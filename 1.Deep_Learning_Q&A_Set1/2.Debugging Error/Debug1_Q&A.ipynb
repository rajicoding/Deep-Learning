# %% [markdown]
# **1. ANN Program**

# %% [raw]
# import numpy as np
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense
#
# # Generate dummy dataset
# data = pd.DataFrame({
#     'Feature1': np.random.rand(100),
#     'Feature2': np.random.rand(100),
#     'Label': np.random.randint(0, 2, size=100)
# })
#
# # Split dataset
# X = data[['Feature1', 'Feature2']]
# y = data['Label']
#
# # Scaling features
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)
#
# X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
#
# # Build ANN Model
# model = Sequential()
# model.add(Dense(16, activation='relu', input_shape=(3,)))
# model.add(Dense(8, activation='relu'))
# model.add(Dense(1, activation='sigmoid'))
#
# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#
# # Train model
# model.fit(X_train, y_train, epochs=20, batch_size=16, validation_split=0.2)
#
# # Evaluate the model
# eval_loss, eval_accuracy = model.evaluate(X_test, y_test)
# print(f"Test Accuracy: {eval_accuracy}")
#
# # Predict
# predictions = model.predict(X_test)
# predicted_classes = (predictions > 0.5).astype(int)
# print(predicted_classes[:10])

# %%
X_train.shape 
# value error : as we specify 3 in input shape but we had only two features in dataset
# Out:
# (80, 2)

# %%
# Correct code
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Generate dummy dataset
data = pd.DataFrame({
    'Feature1': np.random.rand(100),
    'Feature2': np.random.rand(100),
    'Label': np.random.randint(0, 2, size=100)
})

# Split dataset
X = data[['Feature1', 'Feature2']]
y = data['Label']

# Scaling features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Build ANN Model
model = Sequential()
model.add(Dense(16, activation='relu', input_shape=(2,)))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train model
model.fit(X_train, y_train, epochs=20, batch_size=16, validation_split=0.2)

# Evaluate the model
eval_loss, eval_accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {eval_accuracy}")

# Predict
predictions = model.predict(X_test)
predicted_classes = (predictions > 0.5).astype(int)
print(predicted_classes[:10])
# Out:
# Epoch 1/20
# C:\Users\Inst_\anaconda3\envs\aiml1\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.5083 - loss: 0.6942 - val_accuracy: 0.3125 - val_loss: 0.7508
# Epoch 2/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5542 - loss: 0.6852 - val_accuracy: 0.4375 - val_loss: 0.7456
# Epoch 3/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5437 - loss: 0.6732 - val_accuracy: 0.5000 - val_loss: 0.7399
# Epoch 4/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6208 - loss: 0.6709 - val_accuracy: 0.5625 - val_loss: 0.7337
# Epoch 5/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5688 - loss: 0.6698 - val_accuracy: 0.5625 - val_loss: 0.7289
# ...

# %% [markdown]
# ### 2. CNN Program

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# Create sample data
X_train = np.random.rand(100, 28, 28, 1)
y_train = np.random.randint(0, 10, size=(100,))

# Build a simple CNN
model = keras.sequentia([ 
    layers.Conv2D(32, (3, 3), Activatin='relu', input_shape=(28, 28, 1)),  
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=5, batch_size=32)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 10
#       7 y_train = np.random.randint(0, 10, size=(100,))
#       9 # Build a simple CNN
# ---> 10 model = keras.sequentia([  # Error 1: Misspelled 'Sequential'
#      11     layers.Conv2D(32, (3, 3), Activatin='relu', input_shape=(28, 28, 1)),  # Error 2: Misspelled 'activation'
#      12     layers.MaxPooling2D((2, 2)),
#      13     layers.Flatten(),
#      14     layers.Dense(64, activation='relu'),
#      15     layers.Dense(10, activation='softmax')
#      16 ])
#      18 # Compile the model
#      19 model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#
# AttributeError: module 'tensorflow.keras' has no attribute 'sequentia'

# %%
# AttributeError as the spelling is not right for the below
#  'Sequential' is mentioned incorrect
#  'activation' is mentioned incorrect

# %%
# Correct code:
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# Create sample data
X_train = np.random.rand(100, 28, 28, 1)
y_train = np.random.randint(0, 10, size=(100,))

# Build a simple CNN
model = keras.Sequential([ 
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),  
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0985 - loss: 2.3466
# Epoch 2/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.1300 - loss: 2.2959
# Epoch 3/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1102 - loss: 2.2627
# Epoch 4/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1112 - loss: 2.2388
# Epoch 5/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3422 - loss: 2.1762

# %% [markdown]
# ## **3.Library Installation Error (ANN)**

# %%
mport Tensorflow as tf 
from tensorflow import keras
from tensorflow.Keras import layers

print("TensorFlow Version:", tf.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import Tensorflow as tf  # Error: Misspelled 'TensorFlow'
#       2 from tensorflow import keras
#       3 from tensorflow.Keras import layers
#
# ModuleNotFoundError: No module named 'Tensorflow'

# %%
# python is casesensitive the starting letter of the package name is mentioned in caps
# Tensorflow,Keras

# %%
# Correct code:
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
print("Tensorflow Version:", tf.__version__)
# Out:
# Tensorflow Version: 2.19.0

# %% [markdown]
# ## **4.4. ModuleNotFoundError (Using Pretrained Model)**

# %%
from tensorflow.keras.applications import VGG1 
model = VGG1(weights='imagenet')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from tensorflow.keras.applications import VGG1 # Error: VGG1 doesn't exist
#       2 model = VGG1(weights='imagenet')
#
# ImportError: cannot import name 'VGG1' from 'tensorflow.keras.applications' (C:\Users\Inst_\anaconda3\envs\aiml1\Lib\site-packages\keras\_tf_keras\keras\applications\__init__.py)

# %%
# There is no module named VGG1

# %%
# Correct code
from tensorflow.keras.applications import VGG16 
model = VGG16(weights='imagenet')
# Out:
# ...
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 171s 0us/step

# %% [markdown]
# ## **5.TypeError (ANN)**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

X_train = np.random.rand(100, 20)
y_train = np.random.randint(0, 2, size=(100,))

model = tf.keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(20,)),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])


model.fit(X_train, y_train, epochs=5, batch_size=32.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 16
#      13 model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#      15 # TypeError: batch_size should be integer, but passed as a float
# ---> 16 model.fit(X_train, y_train, epochs=5, batch_size=32.0)
#
# File ~\anaconda3\envs\deepL\Lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# ...

# %%
# TypeError: batch_size passed as a float, it should be integer

# %%
#Correct code:
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

X_train = np.random.rand(100, 20)
y_train = np.random.randint(0, 2, size=(100,))

model = tf.keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(20,)),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])


model.fit(X_train, y_train, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# C:\Users\Inst_\anaconda3\envs\aiml1\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4606 - loss: 0.7096
# Epoch 2/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5042 - loss: 0.7023
# Epoch 3/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5083 - loss: 0.6991
# Epoch 4/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5023 - loss: 0.6970
# Epoch 5/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4757 - loss: 0.6951

# %% [markdown]
# ## **6.ValueError (Pretrained Model)**

# %%
from tensorflow.keras.applications import ResNet50
import numpy as np


input_data = np.random.rand(1, 224, 224)  

model = ResNet50(weights='imagenet')
prediction = model.predict(input_data)
# Out:
# ...
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 29s 0us/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 8
#       5 input_data = np.random.rand(1, 224, 224)
#       7 model = ResNet50(weights='imagenet')
# ----> 8 prediction = model.predict(input_data)
#
# File ~\anaconda3\envs\aiml1\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\anaconda3\envs\aiml1\Lib\site-packages\keras\src\models\functional.py:276, in Functional._adjust_input_rank(self, flat_inputs)
# ...

# %%
# Error: expected 4 dimensions, but we gave only 3 and missed to mention the channel dimension

# %%
from tensorflow.keras.applications import ResNet50
import numpy as np


input_data = np.random.rand(1, 224, 224,3)  

model = ResNet50(weights='imagenet')
prediction = model.predict(input_data)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %% [markdown]
# ## **7.ImportError - Missing Library (ANN)**

# %%
import tensoflow as tf  
from tensorflow.keras import layers

model = tf.keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(10,)),
    Layers.Dens(1, activation='sigmoid')
])

print("Model created successfully.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import tensoflow as tf
#       2 from tensorflow.keras import layers
#       4 model = tf.keras.Sequential([
#       5     layers.Dense(32, activation='relu', input_shape=(10,)),
#       6     Layers.Dens(1, activation='sigmoid')
#       7 ])
#
# ModuleNotFoundError: No module named 'tensoflow'

# %%
# Error: Modeule name is not mentioned correct
# mentioned layers as "Layers"
# spelling mistake for Dense

# %%
import tensorflow as tf  
from tensorflow.keras import layers

model = tf.keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(10,)),
    layers.Dense(1, activation='sigmoid')
])

print("Model created successfully.")
# Out:
# Model created successfully.

# %% [markdown]
# ## **8. Attribute Error**

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers


input_data = np.random.rand(1,28, 28)

model = keras.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.Maxpooling2D((2, 2)),
    layers.flatten(),
    layers.Dense(10, activation='softmax')
])


prediction = model.predict(input_data)
# Out:
# C:\Users\Inst_\anaconda3\envs\aiml1\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 10
#       5 # Data with wrong shape (2D instead of 4D)
#       6 input_data = np.random.rand(1,28, 28)
#       8 model = keras.Sequential([
#       9     layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
# ---> 10     layers.Maxpooling2D((2, 2)),
#      11     layers.flatten(),
#      12     layers.Dense(10, activation='softmax')
#      13 ])
#      15 # Error: Input data should have 4 dimensions (batch_size, height, width, channels)
# ...

# %%
# Attribute Error : attribute names are mentioned incorrect 
# MaxPolling2D, Flatten are mentioned incorrect

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers


input_data = np.random.rand(1,28, 28)

model = keras.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(10, activation='softmax')
])


prediction = model.predict(input_data)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step

# %% [markdown]
# ## **9.TypeError - Incorrect Loss Function (ANN)**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

X_train = np.random.rand(100, 10)
y_train = np.random.randint(0, 2, size=(100,))

model = tf.keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(10,)),
    layers.Dense(1, activation='sigmoid')
])


model.compile(optimizer='adam', loss=0.5, metrics=['accuracy'])
model.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 15
#      13 # Error: Loss should be a string or a callable, not a number
#      14 model.compile(optimizer='adam', loss=0.5, metrics=['accuracy'])
# ---> 15 model.fit(X_train, y_train, epochs=5)
#
# File ~\anaconda3\envs\aiml1\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\anaconda3\envs\aiml1\Lib\site-packages\keras\src\losses\__init__.py:207, in get(identifier)
#     205     return obj
#     206 else:
# ...

# %%
# Error: Loss should be a string or a callable, not a number

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

X_train = np.random.rand(100, 10)
y_train = np.random.randint(0, 2, size=(100,))

model = tf.keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(10,)),
    layers.Dense(1, activation='sigmoid')
])


model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=['accuracy'])
model.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# C:\Users\Inst_\anaconda3\envs\aiml1\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4237 - loss: 0.0000e+00
# Epoch 2/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3933 - loss: 0.0000e+00
# Epoch 3/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4107 - loss: 0.0000e+00
# Epoch 4/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4503 - loss: 0.0000e+00
# Epoch 5/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4076 - loss: 0.0000e+00

# %%
# Correct code
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers


input_data = np.random.rand(1,28, 28)

model = keras.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(10, activation='softmax')
])


prediction = model.predict(input_data)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step

# %% [markdown]
# ## **10.Invalid Function Error**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

# Generate random training data
X_train = np.random.rand(100, 10)
y_train = np.random.randint(0, 2, size=(100,))

model = tf.keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(10,)),
    layers.Dense(1, activation='sigmoid')
])


model.compile(optimizer='adm', loss=0.5, metrics=['accuracy'])

model.fit(X_train, y_train, epochs=5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 15
#       7 y_train = np.random.randint(0, 2, size=(100,))
#       9 model = tf.keras.Sequential([
#      10     layers.Dense(32, activation='relu', input_shape=(10,)),
#      11     layers.Dense(1, activation='sigmoid')
#      12 ])
# ---> 15 model.compile(optimizer='adm', loss=0.5, metrics=['accuracy'])
#      17 model.fit(X_train, y_train, epochs=5)
#
# File ~\anaconda3\envs\aiml1\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# ...

# %%
# Error 1: Misspelled optimizer name ('adm' instead of 'adam')
# Error 2: Invalid loss function (should be a string or callable, not a number)

# %%
#Correct code:
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

# Generate random training data
X_train = np.random.rand(100, 10)
y_train = np.random.randint(0, 2, size=(100,))

model = tf.keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(10,)),
    layers.Dense(1, activation='sigmoid')
])


model.compile(optimizer='adam', loss="mse", metrics=['accuracy'])

model.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5636 - loss: 0.2454
# Epoch 2/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6141 - loss: 0.2449
# Epoch 3/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5882 - loss: 0.2450
# Epoch 4/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5820 - loss: 0.2459
# Epoch 5/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5872 - loss: 0.2436
